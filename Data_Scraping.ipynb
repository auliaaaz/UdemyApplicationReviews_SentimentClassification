# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.9 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import app, Sort, reviews
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.udemy.android',
    lang='en',
    count=7000,
    filter_score_with=None
)

df_review = pd.DataFrame(np.array(result), columns=['review'])
df_review = df_review.join(pd.DataFrame(df_review.pop('review').tolist()))
df_review
# Out:
#                                   reviewId       userName  \
# 0     8044d915-fea5-477b-8723-62a2b18d45f2  A Google user
# 1     6721bb8a-f159-4797-9af6-08ee8d91cbbd  A Google user
# 2     f699fcaa-0765-4301-9774-c34a3fd5f70e  A Google user
# 3     4387a7ed-e3d3-40da-9fd0-f74298bde24c  A Google user
# 4     d02711d6-cd30-4153-9728-f3c2590a854b  A Google user
# ...                                    ...            ...
# 6995  edda15ad-94da-4609-8c8c-e74a0c2230b8  A Google user
# 6996  05f00450-033e-40ba-bde8-d7757c233ff4  A Google user
# 6997  d5cca2f7-3d00-47c3-83da-d7c9bbba377d  A Google user
# 6998  a02de8ed-7f88-41ea-8019-f22c60159c47  A Google user
# 6999  b47c174a-20e9-494b-ac76-11707167836e  A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# 3     https://play-lh.googleusercontent.com/EGemoI2N...
# 4     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                 ...
# 6995  https://play-lh.googleusercontent.com/EGemoI2N...
# 6996  https://play-lh.googleusercontent.com/EGemoI2N...
# 6997  https://play-lh.googleusercontent.com/EGemoI2N...
# 6998  https://play-lh.googleusercontent.com/EGemoI2N...
# 6999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 0                                              All okay      5              0
# 1                                           Awesome app      5              0
# 2                                                 great      5              0
# 3     The app has worked well before, but right now,...      3              0
# 4                         interesting app easy to learn      5              0
# ...                                                 ...    ...            ...
# 6995  I'm finding it difficult to create an account,...      1              0
# 6996  Please take a proper steps to casting to Andor...      1              0
# 6997                                        Nice course      4              0
# 6998                                   enjoying the app      5              0
# 6999               very slow specially when downloading      3              0
#
#      reviewCreatedVersion                  at  \
# 0                  9.41.2 2024-11-19 06:59:02
# 1                  9.42.1 2024-11-19 02:10:06
# 2                  9.42.1 2024-11-18 23:00:06
# 3                    None 2024-11-18 22:56:35
# 4                  9.42.0 2024-11-18 19:16:20
# ...                   ...                 ...
# 6995                9.7.0 2023-05-16 21:51:10
# 6996                9.7.0 2023-05-16 20:01:14
# 6997                 None 2023-05-16 17:30:51
# 6998                9.7.0 2023-05-16 16:33:30
# 6999                9.7.0 2023-05-16 15:09:15
#
#                                            replyContent           repliedAt  \
# 0                                                  None                 NaT
# 1                                                  None                 NaT
# 2                                                  None                 NaT
# 3     Hi there,\n\nThanks for reaching out.\n\nPleas... 2024-11-18 23:14:27
# 4                                                  None                 NaT
# ...                                                 ...                 ...
# 6995  Hello!\nThanks for sharing this.\nCan you plea... 2023-05-16 22:16:17
# 6996  Hi Thiyagaraaj. Thanks for reaching out. Pleas... 2023-05-16 20:07:00
# 6997                                               None                 NaT
# 6998                                               None                 NaT
# 6999  Hi there,\n\nThanks for reaching out and we're... 2023-05-16 15:16:19
#
#      appVersion
# 0        9.41.2
# 1        9.42.1
# 2        9.42.1
# 3          None
# 4        9.42.0
# ...         ...
# 6995      9.7.0
# 6996      9.7.0
# 6997       None
# 6998      9.7.0
# 6999      9.7.0
#
# [7000 rows x 11 columns]

# %%
df_review.to_csv("/content/udemy_reviews.csv")
